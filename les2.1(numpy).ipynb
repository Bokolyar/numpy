# %% [markdown]
# # task1

# %%
import numpy as np

# %%
a = np.array([[1,6],
             [2,8],
             [3,11],
             [3,10],
             [1,7]])

# %%
a
# Out:
# array([[ 1,  6],
#        [ 2,  8],
#        [ 3, 11],
#        [ 3, 10],
#        [ 1,  7]])

# %%
mean_a = np.array([a[:,0].mean(),a[:,1].mean()])

# %%
mean_a
# Out:
# array([2. , 8.4])

# %% [markdown]
# # task2

# %%
a_centered = a - mean_a

# %%
a_centered
# Out:
# array([[-1. , -2.4],
#        [ 0. , -0.4],
#        [ 1. ,  2.6],
#        [ 1. ,  1.6],
#        [-1. , -1.4]])

# %% [markdown]
# # task3

# %%
a_centered_sp = a_centered[:,0] @ a_centered[:,1]

# %%
a_centered_sp
# Out:
# 8.0

# %%
a_centered_sp/4
# Out:
# 2.0

# %% [markdown]
# # task4

# %%
x = np.cov(a.T)

# %%
x
# Out:
# array([[1. , 2. ],
#        [2. , 4.3]])

# %%
x[0,1]
# Out:
# 2.0
